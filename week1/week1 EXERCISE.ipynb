# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
from dotenv import load_dotenv
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2:1b'

# %%
# set up environment
load_dotenv()
openai = OpenAI()

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming
result = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=[{"role": "user", "content": question}],
    stream=True
)
for chunk in result:
    print(chunk.choices[0].delta.content)
# Out:
# The
#  code
#  you
#  provided
#  is
#  a
#  Python
#  statement
#  that
#  uses
#  a
#  generator
#  to
#  yield
#  values
# .
#  Let's
#  break
#  it
#  down
# :
#
#
# 1
# .
#  **
# Set
#  Com
# preh
# ension
# **
# :
#
#
#
#  -
#  The
#  part
#  `{
# book
# .get
# ("
# author
# ")
#  for
#  book
#  in
#  books
#  if
#  book
# .get
# ("
# author
# ")
# }`
#  is
#  a
#  set
#  comprehension
# .
#
#
#
#  -
#  It
#  iter
# ates
#  over
#  a
#  collection
#  called
#  `
# books
# `,
#  which
#  is
#  assumed
#  to
#  be
#  a
#  list
#  (
# or
#  another
#  iterable
# )
#  of
#  dictionaries
# .
#
#
#  -
#  For
#  each
#  `
# book
# `
#  in
#  `
# books
# `,
#  it
#  tries
#  to
#  get
#  the
#  value
#  associated
#  with
#  the
#  key
#  `"
# author
# "`
#  using
#  `
# book
# .get
# ("
# author
# ")
# `.
#
#
#  -
#  The
#  `
# if
#  book
# .get
# ("
# author
# ")
# `
#  part
#  is
#  a
#  condition
#  that
#  ensures
#  only
#  the
#  authors
#  that
#  exist
#  (
# i
# .e
# .,
#  are
#  not
#  `
# None
# `
#  or
#  empty
# )
#  are
#  included
#  in
#  the
#  set
# .
#
#
# 2
# .
#  **
# Creating
#  a
#  Set
# **
# :
#
#
#  -
#  The
#  result
#  of
#  the
#  set
#  comprehension
#  is
#  a
#  set
#  of
#  unique
#  authors
#  from
#  the
#  `
# books
# `.
#
#
#
#  -
#  Since
#  sets
#  inherently
#  do
#  not
#  allow
#  duplicate
#  values
# ,
#  any
#  duplicate
#  authors
#  will
#  be
#  filtered
#  out
#  automatically
# .
#
#
# 3
# .
#  **
# `
# yield
#  from
# `
#  Statement
# **
# :
#
#
#  -
#  The
#  `
# yield
#  from
# `
#  statement
#  is
#  used
#  to
#  yield
#  all
#  values
#  from
#  an
#  iterable
#  (
# in
#  this
#  case
# ,
#  the
#  set
#  of
#  authors
# )
#  one
#  by
#  one
# .
#
#
#  -
#  This
#  allows
#  for
#  a
#  generator
#  function
#  or
#  context
#  to
#  produce
#  multiple
#  output
#  values
#  without
#  having
#  to
#  explicitly
#  iterate
#  through
#  the
#  set
#  and
#  yield
#  each
#  one
#  individually
# .
#
#
# ###
#  Summary
# :
#
# -
#  This
#  code
#  effectively
#  creates
#  a
#  generator
#  that
#  yields
#  each
#  unique
#  author
#  from
#  the
#  `
# books
# `
#  iterable
# ,
#  as
#  long
#  as
#  the
#  author
#  is
#  defined
#  (
# i
# .e
# .,
#  it
#  is
#  not
#  `
# None
# `
#  or
#  empty
# ).
#
# -
#  It
#  serves
#  the
#  purpose
#  of
#  simplifying
#  the
#  process
#  of
#  collecting
#  and
#  yielding
#  unique
#  authors
#  from
#  a
#  list
#  of
#  books
# .
#
#
# ###
#  Example
#  Usage
# :
#
# If
#  you
#  had
#  a
#  list
#  of
#  book
#  dictionaries
# ,
#  like
#  this
# :
#
#
# ```
# python
#
#
# books
#  =
#  [
#
#
#  {"
# title
# ":
#  "
# Book
#
# 1
# ",
#  "
# author
# ":
#  "
# Author
#  A
# "},
#
#
#  {"
# title
# ":
#  "
# Book
#
# 2
# ",
#  "
# author
# ":
#  "
# Author
#  B
# "},
#
#
#  {"
# title
# ":
#  "
# Book
#
# 3
# ",
#  "
# author
# ":
#  "
# Author
#  A
# "},
#
#
#  {"
# title
# ":
#  "
# Book
#
# 4
# "},
#
#  #
#  No
#  author
#
#
#
#  {"
# title
# ":
#  "
# Book
#
# 5
# ",
#  "
# author
# ":
#  "
# Author
#  C
# "},
#
# ]
#
#
# #
#  Using
#  the
#  code
# :
#
# yield
#  from
#  {
# book
# .get
# ("
# author
# ")
#  for
#  book
#  in
#  books
#  if
#  book
# .get
# ("
# author
# ")}
#
# ``
# `
#
#
# Would
#  yield
# :
#
#
# -
#  `
# Author
#  A
# `,
#
#
# -
#  `
# Author
#  B
# `,
#
#
# -
#  `
# Author
#  C
# `
#
#
#
# Each
#  author
#  would
#  be
#  yielded
#  just
#  once
#  due
#  to
#  the
#  nature
#  of
#  sets
# .
# None

# %%
# Get Llama 3.2 to answer

ollama = OpenAI(base_url="http://localhost:11434/v1")
result = ollama.chat.completions.create(
    model=MODEL_LLAMA,
    messages=[{"role": "user", "content": question}],
)
print(result.choices[0].message.content)
# Out:
# This code uses a technique called iterator yielding (or generator expression) to filter a list of dictionaries, `books`, based on the "author" field.
#
# Here's a breakdown:
#
# - `yield from`: This is a syntax sugar that allows you to simplify an iterator in one line. It creates an iterator that will yield each item from the iterable when it reaches the end.
#
# - `{book.get("author") for book in books if book.get("author")}`: This part of the code selects specific items (in this case, the "author" field) from the `books` list and checks if they exist.
#
#   - `"for book in books`: It iterates over each dictionary (`Book`) in the `books` list.
#
#   - `if book.get("author")`: This checks if the value of the "author" key is not null or empty. Only items where this condition is true will be yielded to subsequent `yield from` blocks, which means only the desired authors' details are processed.
#
# - `yielded_value = yield_from(...)`: Each item yielded by `yield from` gets an underscore prefixed before it. So when a function that uses `yield from {...}` encounters the same value multiple times, each one is used as the "index" to fetch the next set of values and be returned instead of having its original name returned.
#
# This code essentially returns all authors of books where they are authors in some form (like titles etc), without returning any book data itself. The authors' details of other books will depend on you defining a function that will be called by `yield from {}`.
#
# Here's an example to illustrate this:
#
# ```python
# class Book:
#     def __init__(self, title, author):
#         self.title = title
#         self.author = author
#
#     def get(self, key):
#         return getattr(self, key)
#
#
# books = [
#     Book("Book1", "Author1"),
#     Book("Book2", None),
#     Book("Book3", "Author4")
# ]
#
# def process_books():
#     for book in books:
#         yield from [book.get(key) for key in ["author"] if book.get(key)]
#
# for (key, value) in process_books().items():
#     print(f"{key}: {value}")
# ```
#
# When you run this script, the output would be:
#
# ```python
# author: Author1
# ```
